# %% [markdown]
# # Distributed Training with TorchX and Ray
#
# Training models on large clusters is challenging for a few reasons
# 1. Need to setup an infrastructure
# 2. Need a way to submit jobs like distributed training scripts
# 3. Need a way to monitor the status jobs, aggregate logs from several machinees and collect artifacts when model training is done
#
# With the new torchX Ray scheduler this process has been dramatically simplified.

# %%
# Ray scheduler for torchX is an experimental feature
! pip install git+https://github.com/pytorch/torchx.git@raydriver -q

# %%
! pip install "ray[default]" -q

# %% [markdown]
# ## Infrastructure setup
#
# Ray provides a feature called `ray up cluster.yaml` which given a YAML file and access to your cloud credentials (e.g: AWS, GCP, Azure) will go ahead and setup an infrastructure for you.
#
# Let's take a look at what the script looks like

# %%
! cat ray_cluster.yaml
# Out:
# # An unique identifier for the head node and workers of this cluster.
# cluster_name: gpu-docker
#
# min_workers: 1
# max_workers: 4
#
# # The autoscaler will scale up the cluster faster with higher upscaling speed.
# # E.g., if the task requires adding more nodes then autoscaler will gradually
# # scale up the cluster in chunks of upscaling_speed*currently_running_nodes.
# # This number should be > 0.
# upscaling_speed: 1.0
#
# # This executes all commands on all nodes in the docker container,
# # and opens all the necessary ports to support the Ray cluster.
# # Empty string means disabled.
# docker:
#   image: "rayproject/ray-ml:latest-gpu"
#   # image: rayproject/ray:latest-gpu   # use this one if you don't need ML dependencies, it's faster to pull
#   container_name: "ray_nvidia_docker" # e.g. ray_docker
#
#
# # If a node is idle for this many minutes, it will be removed.
# idle_timeout_minutes: 5
#
# # Cloud-provider specific configuration.
# provider:
#   type: aws
#   region: us-west-2
#   # Availability zone(s), comma-separated, that nodes may be launched in.
#   # Nodes are currently spread between zones by a round-robin approach,
#   # however this implementation detail should not be relied upon.
#   availability_zone: us-west-2a,us-west-2b
#   security_group:
#     GroupName: dashboard_group
#     IpPermissions:
#       - FromPort: 20002
#         ToPort: 20002
#         IpProtocol: TCP
#         IpRanges:
#           - CidrIp: 0.0.0.0/0
#
#
# # How Ray will authenticate with newly launched nodes.
# auth:
#   ssh_user: ubuntu
# # By default Ray creates a new private keypair, but you can also use your own.
# # If you do so, make sure to also set "KeyName" in the head and worker node
# # configurations below.
# #    ssh_private_key: /path/to/your/key.pem
#
# # Tell the autoscaler the allowed node types and the resources they provide.
# # The key is the name of the node type, which is just for debugging purposes.
# # The node config specifies the launch config and physical instance type.
# available_node_types:
#   # GPU head node.
#   ray.head.gpu:
#     # worker_image: rayproject/ray:latest-gpu   # use this one if you don't need ML dependencies, it's faster to pull
#     # The node type's CPU and GPU resources are auto-detected based on AWS instance type.
#     # If desired, you can override the autodetected CPU and GPU resources advertised to the autoscaler.
#     # You can also set custom resources.
#     # For example, to mark a node type as having 1 CPU, 1 GPU, and 5 units of a resource called "custom", set
#     # resources: {"CPU": 1, "GPU": 1, "custom": 5}
#     resources: {}
#     # Provider-specific config for this node type, e.g. instance type. By default
#     # Ray will auto-configure unspecified fields such as SubnetId and KeyName.
#     # For more documentation on available fields, see:
#     # http://boto3.readthedocs.io/en/latest/reference/services/ec2.html#EC2.ServiceResource.create_instances
#     node_config:
#       InstanceType: p2.xlarge
#       ImageId: ami-0a2363a9cff180a64 # Deep Learning AMI (Ubuntu) Version 30
#       # You can provision additional disk space with a conf as follows
#       BlockDeviceMappings:
#         - DeviceName: /dev/sda1
#           Ebs:
#             VolumeSize: 100
#       # Additional options in the boto docs.
#   # CPU workers.
#   ray.worker.default:
#     # Override global docker setting.
#     # This node type will run a CPU image,
#     # rather than the GPU image specified in the global docker settings.
#     docker:
#       worker_image: "rayproject/ray-ml:latest-cpu"
#     # The minimum number of nodes of this type to launch.
#     # This number should be >= 0.
#     min_workers: 1
#     # The maximum number of workers nodes of this type to launch.
#     # This takes precedence over min_workers.
#     max_workers: 2
#     # The node type's CPU and GPU resources are auto-detected based on AWS instance type.
#     # If desired, you can override the autodetected CPU and GPU resources advertised to the autoscaler.
#     # You can also set custom resources.
#     # For example, to mark a node type as having 1 CPU, 1 GPU, and 5 units of a resource called "custom", set
#     # resources: {"CPU": 1, "GPU": 1, "custom": 5}
#     resources: {}
#     # Provider-specific config for this node type, e.g. instance type. By default
#     # Ray will auto-configure unspecified fields such as SubnetId and KeyName.
#     # For more documentation on available fields, see:
#     # http://boto3.readthedocs.io/en/latest/reference/services/ec2.html#EC2.ServiceResource.create_instances
#     node_config:
#       InstanceType: m5.large
#       ImageId: ami-0a2363a9cff180a64 # Deep Learning AMI (Ubuntu) Version 30
#       # Run workers on spot by default. Comment this out to use on-demand.
#       InstanceMarketOptions:
#         MarketType: spot
#         # Additional options can be found in the boto docs, e.g.
#         #   SpotOptions:
#         #       MaxPrice: MAX_HOURLY_PRICE
#       # Additional options in the boto docs.
#
# # Specify the node type of the head node (as configured above).
# head_node_type: ray.head.gpu
#
# # Files or directories to copy to the head and worker nodes. The format is a
# # dictionary from REMOTE_PATH: LOCAL_PATH, e.g.
# file_mounts: {
#   #    "/path1/on/remote/machine": "/path1/on/local/machine",
#   #    "/path2/on/remote/machine": "/path2/on/local/machine",
# }
#
# # List of shell commands to run to set up nodes.
# # NOTE: rayproject/ray:latest has ray latest bundled
# setup_commands: []
# # - pip install -U https://s3-us-west-2.amazonaws.com/ray-wheels/latest/ray-2.0.0.dev0-cp36-cp36m-manylinux2014_x86_64.whl
# # - pip install -U "ray[default] @ https://s3-us-west-2.amazonaws.com/ray-wheels/latest/ray-2.0.0.dev0-cp37-cp37m-manylinux2014_x86_64.whl"
#
# # Custom commands that will be run on the head node after common setup.
# head_setup_commands:
#   - pip install boto3==1.4.8  # 1.4.8 adds InstanceMarketOptions
#
# # Custom commands that will be run on worker nodes after common setup.
# worker_setup_commands: []
#
# # Command to start ray on the head node. You don't need to change this.
# head_start_ray_commands:
#   - ray stop
#   - ulimit -n 65536; ray start --dashboard-port 20002 --dashboard-host=0.0.0.0 --include-dashboard True --head --port=6379 --object-manager-port=8076 --autoscaling-config=~/ray_bootstrap_config.yaml
#
# # Command to start ray on worker nodes. You don't need to change this.
# worker_start_ray_commands:
#   - ray stop
#   - ulimit -n 65536; ray start --address=$RAY_HEAD_IP:6379 --object-manager-port=8076

# %% [markdown]
# ## Understanding `ray_cluster.yaml`
#
# 1. docker: provides link to the docker images that will be setup on the cluster which is an easy way to setup your dependencies
# 2. provider: determine your cloud provider and region
# 3. GroupName: jobs will be submitted against a Ray endpoint called the dashboard
# 4. resources: to determine the number of CPUs and GPUs allocated to each node - try making this number bigger
# 5. node_config: the machine instance type, AMI and options for spot instances for cheaper training
# 5. commands to start on worker or head nodes: you don't need to change these, they're what make it easier for you to setup your infra instead of
#
# To learn more about available options make sure to visit https://docs.ray.io/en/latest/cluster/config.html
#
# In this tutorial we're going to be running on AWS but running on a different cloud provider should just be a simple config change

# %% [markdown]
# ## Setup aws cli
#
# Since we're running on aws you're going to need to
# 1. Install the AWS cli https://docs.aws.amazon.com/cli/latest/userguide/getting-started-install.html
# 2. Configure the AWS cli by running `aws configure` https://docs.aws.amazon.com/cli/latest/userguide/cli-configure-quickstart.html
#
# And now we can start doing deep learning stuff

# %%
import ray

# %%
# Having some issues with ray up taking forever
# Stop existing instances of Ray
! ray stop --force

# Setup ray cluster
# This may take a few minutes - Ray will retry several ssh connections before succeeding
! ray up ray_cluster.yaml -y
# Out:
#     SSH still not available (SSH command failed.), retrying in 5 seconds.

# %%
# %%writefile ray_simple.py
def main() -> None:
    print("hello")
    return


if __name__ == "__main__":
    main()
# Out:
# Writing ray_simple.py

# %%
! ray stop --force
# Out:
# Stopped all 2 Ray processes.

# %%
! ray start --head
# Out:
# Local node IP: 172.31.51.124
# 2022-01-26 01:00:32,703	INFO services.py:1338 -- View the Ray dashboard at http://127.0.0.1:8265
#
# --------------------
# Ray runtime started.
# --------------------
#
# Next steps
#   To connect to this Ray runtime from another node, run
#     ray start --address='172.31.51.124:6379' --redis-password='5241590000000000'
#
#   Alternatively, use the following Python code:
#     import ray
#     ray.init(address='auto', _redis_password='5241590000000000')
#
#   To connect to this Ray runtime from outside of the cluster, for example to
#   connect to a remote cluster from your laptop directly, use the following
#   Python code:
#     import ray
#     ray.init(address='ray://<head_node_ip_address>:10001')
#
#   If connection fails, check your firewall settings and network configuration.
#
#   To terminate the Ray runtime, run
#     ray stop

# %%
! ray start --address='172.31.51.124:6379' --redis-password='5241590000000000'
# Out:
# Local node IP: 172.31.51.124
# 2022-01-26 01:00:52,490	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158852.490743112","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158852.490742074","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:00:53,492	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158853.492577356","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158853.492576516","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:00:54,494	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158854.494567779","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158854.494566951","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:00:55,496	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158855.496552682","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158855.496551615","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:00:56,498	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158856.498593812","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158856.498592995","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:00:57,500	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158857.500569298","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158857.500568492","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:00:59,503	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158859.503125358","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158859.503124293","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:00,505	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158860.505186768","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158860.505185922","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:01,507	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158861.507147278","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158861.507146507","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:02,509	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158862.509133265","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158862.509132399","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:03,511	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158863.511118215","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158863.511117350","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:04,513	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158864.513115012","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158864.513114138","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:06,515	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158866.515669612","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158866.515668703","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:07,517	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158867.517660240","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158867.517659431","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:08,519	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158868.519622682","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158868.519621924","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:09,521	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158869.521617147","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158869.521616241","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:10,523	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158870.523593383","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158870.523592558","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:11,525	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158871.525564577","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158871.525563770","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:13,528	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158873.528120096","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158873.528119014","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:14,530	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158874.530115921","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158874.530114960","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:15,532	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158875.532103821","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158875.532102974","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:16,534	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158876.534072687","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158876.534071896","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:17,536	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158877.536060280","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158877.536059438","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:18,538	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158878.538062088","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158878.538061155","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:20,540	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158880.540616897","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158880.540615959","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:21,542	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158881.542683560","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158881.542682566","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:22,544	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158882.544668708","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158882.544667847","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:23,546	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158883.546679270","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158883.546678296","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:24,548	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158884.548659692","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158884.548658469","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:25,550	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158885.550639475","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158885.550638587","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:27,553	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158887.553072390","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158887.553071274","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:28,555	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158888.555112164","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158888.555111190","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:29,557	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158889.557127109","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158889.557126179","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:30,559	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158890.559089785","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158890.559088865","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:31,561	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158891.561095988","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158891.561081223","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:32,563	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158892.563090949","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158892.563090057","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:34,565	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158894.565631064","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158894.565630116","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:35,567	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158895.567636178","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158895.567635372","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:36,569	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158896.569637997","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158896.569637043","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:37,571	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158897.571640152","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158897.571639214","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:38,573	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158898.573634934","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158898.573633770","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:39,575	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158899.575630800","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158899.575629926","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:41,578	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158901.578189277","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158901.578188420","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:42,580	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158902.580261014","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158902.580260168","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:43,582	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158903.582287131","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158903.582282029","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:44,584	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158904.584282849","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158904.584281972","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:45,586	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158905.586286336","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158905.586285434","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:46,588	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158906.588299895","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158906.588299067","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:48,591	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158908.590891138","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158908.590890155","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:49,593	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158909.592945488","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158909.592944567","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:50,595	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158910.594966521","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158910.594965657","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:51,597	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158911.596967832","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158911.596966841","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:52,599	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158912.598977252","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158912.598976281","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:53,601	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158913.600946674","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158913.600945712","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:55,603	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158915.603508126","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158915.603507292","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:56,605	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158916.605542282","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158916.605541406","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:57,607	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158917.607530949","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158917.607530028","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:58,609	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158918.609507537","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158918.609506725","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:01:59,611	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158919.611467519","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158919.611466596","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:00,613	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158920.613465284","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158920.613464370","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:02,616	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158922.615885660","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158922.615884418","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:03,618	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158923.617889067","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158923.617888130","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:04,620	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158924.619904057","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158924.619903185","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:05,621	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158925.621536857","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158925.621536003","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:06,623	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158926.623483642","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158926.623482754","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:07,625	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158927.625452516","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158927.625451420","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:09,628	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158929.627997796","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158929.627996942","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:10,630	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158930.630011011","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158930.630010119","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:11,632	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158931.632005548","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158931.632004671","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:12,634	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158932.633987287","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158932.633986461","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:13,636	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158933.635988272","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158933.635987405","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:14,638	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158934.638117652","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158934.638116809","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:16,640	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158936.640704664","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158936.640703793","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:17,642	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158937.642807837","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158937.642806885","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:18,645	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158938.644827166","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158938.644826231","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:19,647	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158939.646903698","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158939.646902738","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:20,649	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158940.648938281","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158940.648937347","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:21,651	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158941.651026885","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158941.651025879","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:23,653	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158943.653656571","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158943.653655610","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:24,655	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158944.655768472","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158944.655767514","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:25,657	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# ...
# >
# 2022-01-26 01:02:44,692	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158964.692302167","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158964.692301333","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:45,694	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158965.694414907","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158965.694414060","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:46,696	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158966.696472428","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158966.696471598","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:47,698	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158967.698522502","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158967.698521632","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:48,700	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158968.700575157","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158968.700574345","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:49,702	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158969.702647329","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158969.702646495","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:51,705	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158971.705251622","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158971.705250612","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:52,707	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158972.707332826","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158972.707331812","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:53,709	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158973.709418748","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158973.709417933","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:54,711	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158974.711476680","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158974.711475914","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:55,713	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158975.713539767","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158975.713538782","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:56,715	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158976.715589060","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158976.715588311","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:58,718	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158978.718197433","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158978.718196562","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:02:59,720	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158979.720313980","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158979.720312994","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:00,722	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158980.722392562","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158980.722391728","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:01,724	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158981.724454738","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158981.724453931","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:02,726	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158982.726519085","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158982.726518144","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:03,728	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158983.728592982","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158983.728592050","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:05,731	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158985.731184735","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158985.731183813","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:06,733	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158986.733299509","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158986.733298561","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:07,735	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158987.735384722","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158987.735383582","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:08,737	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158988.737462596","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158988.737461717","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:09,739	ERROR gcs_utils.py:136 -- Failed to send request to gcs, reconnecting. Error <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158989.739528361","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158989.739527524","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# 2022-01-26 01:03:10,741	ERROR node.py:1286 -- ERROR as <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses"
# 	debug_error_string = "{"created":"@1643158990.741603301","description":"Failed to pick subchannel","file":"src/core/ext/filters/client_channel/client_channel.cc","file_line":3093,"referenced_errors":[{"created":"@1643158990.741602485","description":"failed to connect to all addresses","file":"src/core/lib/transport/error_utils.cc","file_line":163,"grpc_status":14}]}"
# >
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/ray/bin/ray", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/scripts/scripts.py", line 1989, in main
#     return cli()
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/scripts/scripts.py", line 750, in start
#     node = ray.node.Node(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/node.py", line 147, in __init__
#     session_name = self._internal_kv_get_with_retry(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/node.py", line 1295, in _internal_kv_get_with_retry
#     raise RuntimeError(f"Could not read '{key}' from GCS (redis). "
# RuntimeError: Could not read 'b'session_name'' from GCS (redis). Has redis started correctly on the head node?

# %%
# Pick up the Ray dashboard address to execute a job against it
# Provide a path to your working directory with dependencies along with the script you want to run
! torchx run -s ray -cfg dashboard_address=172.31.51.124:20002,working_dir=. utils.binary --entrypoint ray_simple.py
# Out:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connectionpool.py", line 394, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connection.py", line 239, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/http/client.py", line 1302, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/http/client.py", line 1251, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/http/client.py", line 1011, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/http/client.py", line 951, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fcb890277c0>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='172.31.51.124', port=20002): Max retries exceeded with url: /api/version (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fcb890277c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/dashboard/modules/job/sdk.py", line 95, in _check_connection_and_version
#     r = self._do_request("GET", "/api/version")
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/dashboard/modules/job/sdk.py", line 123, in _do_request
#     return requests.request(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='172.31.51.124', port=20002): Max retries exceeded with url: /api/version (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fcb890277c0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/ray/bin/torchx", line 8, in <module>
#     sys.exit(main())
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/cli/main.py", line 110, in main
#     run_main(get_sub_cmds(), argv)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/cli/main.py", line 106, in run_main
#     args.func(args)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/cli/cmd_run.py", line 204, in run
#     self._run(runner, args)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/cli/cmd_run.py", line 167, in _run
#     app_handle = runner.run_component(
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/runner/api.py", line 136, in run_component
#     return self.schedule(dryrun_info)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/runner/api.py", line 208, in schedule
#     app_id = sched.schedule(dryrun_info)
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/torchx/schedulers/ray_scheduler.py", line 160, in schedule
#     client: JobSubmissionClient = JobSubmissionClient(f"http://{ip_address}")
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/dashboard/modules/job/sdk.py", line 91, in __init__
#     self._check_connection_and_version()
#   File "/home/ubuntu/anaconda3/envs/ray/lib/python3.8/site-packages/ray/dashboard/modules/job/sdk.py", line 105, in _check_connection_and_version
#     raise ConnectionError(
# ConnectionError: Failed to connect to Ray at address: http://172.31.51.124:20002.

# %% [markdown]
# ## Hello torchX Ray scheduler
#
# The way the scheduler works is it either needs a dashboard address to point jobs or it can use your `ray_cluster.yaml` to identify your cluster. Once the cluster is setup you can use the `torchx` cli to submit jobs by specifying a `working_dir` with all your files and data and an an `entrypoint` for a binary script a.k.a your training script.
#
# After deploying a job you'll get a job ID and can use it to determine the status of your job and inspect its logs.

# %%
! torchx run -s ray -cfg cluster_config_file=ray_cluster.yaml,working_dir=. utils.binary --entrypoint ray_simple.py

# %%
# Get a job ID from deployed job
torchx run -s ray -cfg dashboard_address=34.209.89.185:20002,working_dir=test_dir utils.binary --entrypoint ray_simple.py

# Job ID looks like etc..

# Get a job status
# PENDING, FAILED, INTERRUPTED ETC..
torchx describe ray://torchx/34.209.89.185:20002-raysubmit_aKvezN3NyA2mqZeW

# Get job logs
# Aggregatee logs from all machinees in the same place
torchx log ray://torchx/34.209.89.185:20002-raysubmit_aKvezN3NyA2mqZeW

# %% [markdown]
# ## Writing a distributed PyTorch Script
#
# Unfortunately it's currently not possible to automagically make a PyTorch script distributed but it's not too complicated and we'll walk through the steps to do so right now.
# We're going to turn this example of a resnet training loop https://github.com/pytorch/examples/blob/master/mnist/main.py and use the Distributed Data Parallel version of it by github.com/yqhu

# %%
# %%writefile ddp_resnet_train.py
#!/usr/bin/env python3
# Imports
import os
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR

import torch.distributed as dist
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data.distributed import DistributedSampler
# Out:
# Overwriting ddp_resnet_train.py

# %%
# %%writefile ddp_resnet_train.py -a
# # Setup scripts to setup MASTER_ADDR AND MASTER_PORT
# # World size is the number of nodes in a distributed setting
# # Rank is the ID of a specific node in a distributed setting
# # Gloo is a popular backend for internode communication
# def setup(rank, world_size):
#     os.environ['MASTER_ADDR'] = 'localhost'
#     os.environ['MASTER_PORT'] = '12355'
#
#     # initialize the process group
#     backend = "gloo"
#     dist.init_process_group(backend=backend, init_method=f"tcp://{master_addr}:{master_port}", rank=rank, world_size=world_size)
#
#
# def cleanup():
#     dist.destroy_process_group()
# Out:
# Appending to ddp_resnet_train.py

# %%
! cat ddp_resnet_train.py
# Out:
# a = 2
# a = 2
